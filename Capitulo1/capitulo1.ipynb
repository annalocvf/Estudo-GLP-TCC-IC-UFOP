# %% [markdown]
# <a href="https://colab.research.google.com/github/annalocvf/Estudo-GLP-TCC-IC-UFOP/blob/main/Capitulo1/capitulo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #FIGURA 1
#
# Nota
#
# Os dados foram originalmente publicados na em Nota Técnica da EPE (https://www.epe.gov.br/sites-pt/publicacoes-dados-abertos/publicacoes/PublicacoesArquivos/publicacao-413/topico-712/NT-EPE-DPG-SDB-2024-02_GLP_2024.05.13.pdf).
#
# Neste repositório, eles foram organizados e estruturados apenas para facilitar o processamento e a reprodução das análises, sem alteração de seu conteúdo original.

# %%
import pandas as pd

url = 'https://github.com/annalocvf/Estudo-GLP-TCC-IC-UFop/raw/main/Capitulo1/figura1.xlsx'

df_excel = pd.read_excel(url)

print("DataFrame carregado com sucesso:")
display(df_excel.head())
# Out:
# DataFrame carregado com sucesso:
#   Classe de Rendimento  Rendimento Médio (R$)  Preço Botijão / Rendimento (%)
# 0              Até 10%                    163                              67
# 1            10% a 20%                    379                              29
# 2            20% a 30%                    547                              20
# 3            30% a 40%                    702                              16
# 4            40% a 60%                   1006                              11

# %% [markdown]
# ##Rendimento e Peso do Botijão de GLP
#
# Este código utiliza as bibliotecas Matplotlib e NumPy para gerar um gráfico que compara o rendimento domiciliar per capita por classe de renda com o peso do preço do botijão P-13 em relação à renda média.

# %%
import matplotlib.pyplot as plt
import numpy as np

classes = df_excel['Classe de Rendimento'].tolist()
rendimento = df_excel['Rendimento Médio (R$)'].tolist()
percentual = df_excel['Preço Botijão / Rendimento (%)'].tolist()

x = np.arange(len(classes))

fig, ax1 = plt.subplots(figsize=(12, 7))

ax1.bar(x, rendimento, color='skyblue', label='Rendimento domiciliar per capita')
ax1.set_ylabel("Rendimento médio (R$)", fontsize='medium')
ax1.set_xticks(x)
ax1.set_xticklabels(classes, rotation=45, ha='right')
ax1.set_xlabel("Classes de Rendimento Domiciliar Per Capita", fontsize='medium')

ax2 = ax1.twinx()
ax2.plot(x, percentual, marker='o', color='red', label='Preço do Botijão P-13 / Rendimento Médio (%)')
ax2.set_ylabel("Preço do Botijão P-13 / Rendimento Médio (%)", fontsize='medium')

for i, v in enumerate(rendimento):
    ax1.text(i, v + (max(rendimento) * 0.02), f"R$ {v}", ha='center', va='bottom')

for i, p in enumerate(percentual):
    ax2.text(i + 0.05, p + (max(percentual) * 0.02), f"{p}%", ha='left', va='bottom')

# Add a title
plt.title("Rendimento domiciliar per capita e peso do botijão P-13\nBrasil - 2022", fontsize='large')

# Add the legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left', bbox_to_anchor=(0.0, 1.15), frameon=False, fontsize='medium')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Figura 2 – Evolução dos preços de GLP
#
# DADOS DE 2025
#
# Fonte dos dados:
# https://www.sindigas.org.br/Download/DADOS-ESTATISTICOS/MARGEM/2025-margens-p13-tabela.pdf
#
# Os dados utilizados neste gráfico foram extraídos da tabela “Evolução dos preços de GLP (R$ / botijão de 13 kg)”, disponibilizada pelo Sindigás com base em informações da Agência Nacional do Petróleo, Gás Natural e Biocombustíveis (ANP).
#
# O documento apresenta a decomposição do preço do botijão P-13, mostrando os principais componentes da formação do preço ao longo do tempo.
#
# - preço de realização do produtor
# - ICMS
# - margem bruta de distribuição
# - preço de distribuição
# - margem bruta de revenda
# - preço final ao consumidor
#
# As margens de distribuição e de revenda são calculadas a partir dos dados do levantamento de Preços da ANP, que monitora semanalmente os preços praticados no mercado brasileiro de combustíveis.
#
# Como o arquivo original está em formato PDF, os dados foram extraídos e organizados manualmente em uma planilha Excel, permitindo o tratamento das informações e a geração dos gráficos utilizados nesta análise.

# %%
import pandas as pd

#URL do arquivo Excel no Github
url_figura2 = 'https://github.com/annalocvf/Estudo-GLP-TCC-IC-UFOP/raw/main/Capitulo1/figura2.xlsx'


df_figura2 = pd.read_excel(url_figura2)

print("DataFrame 'df_figura2' carregado com sucesso:")
display(df_figura2.head())
# Out:
# DataFrame 'df_figura2' carregado com sucesso:
#                          Indicador    Jan    Fev    Mar    Abr    Mai    Jun  \
# 0  Preço de Realização do Produtor  37.07  37.21  37.35  39.25  38.18  38.65
# 1        Preço do Produtor s/ ICMS  37.07  37.21  37.35  39.25  38.18  38.66
# 2                             ICMS  18.38  18.07  18.07  18.07  18.07  18.07
# 3     Margem Bruta de Distribuição  22.09  22.46  23.16  20.66  22.74  22.11
# 4            Preço de Distribuição  77.54  77.74  78.58  77.98  78.99  78.83
#
#      Jul    Ago    Set    Out    Nov    Dez
# 0  38.82  38.06  38.61  36.46  36.25  36.27
# 1  38.83  38.06  38.61  36.47  36.25  36.27
# 2  18.07  18.07  18.07  18.07  18.07  18.07
# 3  21.29  21.82  22.61  25.57  25.14  24.21
# 4  78.18  77.95  79.29  80.10  79.46  78.55

# %%
print("\nInformações gerais do DataFrame 'df_figura2':\n")
df_figura2.info()

print("\nNomes das colunas de 'df_figura2':\n")
print(df_figura2.columns)

print("\nValores únicos na coluna 'Indicador':\n")
print(df_figura2['Indicador'].unique())
# Out:
# Informações gerais do DataFrame 'df_figura2':
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Indicador  7 non-null      object
#  1   Jan        7 non-null      float64
#  2   Fev        7 non-null      float64
#  3   Mar        7 non-null      float64
#  4   Abr        7 non-null      float64
#  5   Mai        7 non-null      float64
#  6   Jun        7 non-null      float64
#  7   Jul        7 non-null      float64
#  8   Ago        7 non-null      float64
#  9   Set        7 non-null      float64
#  10  Out        7 non-null      float64
#  11  Nov        7 non-null      float64
#  12  Dez        7 non-null      float64
# dtypes: float64(12), object(1)
# memory usage: 860.0+ bytes
#
# Nomes das colunas de 'df_figura2':
#
# Index(['Indicador', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago',
#        'Set', 'Out', 'Nov', 'Dez'],
#       dtype='object')
#
# Valores únicos na coluna 'Indicador':
#
# ['Preço de Realização do Produtor' 'Preço do Produtor s/ ICMS' 'ICMS'
#  'Margem Bruta de Distribuição' 'Preço de Distribuição'
#  'Margem Bruta de Revenda' 'Preço Final ao Consumidor']

# %%
target_indicators = [
    'Margem Bruta de Revenda',
    'Margem Bruta de Distribuição',
    'Preço de Realização do Produtor',
    'ICMS',
    'Preço Final GLP P13'
]

df_figura2['Indicador'] = df_figura2['Indicador'].str.strip()

monthly_columns = [col for col in df_figura2.columns if col not in ['Indicador']]
medias_setores_atualizadas = {}

print("\nMédias mensais dos indicadores:")
for setor in target_indicators:

    current_setor = setor
    if setor == 'Preço Final GLP P13' and setor not in df_figura2['Indicador'].unique():
        if 'Preço Final ao Consumidor' in df_figura2['Indicador'].unique():
            current_setor = 'Preço Final ao Consumidor'
        else:
            print(f"  - '{setor}' ou 'Preço Final ao Consumidor' não encontrado.")
            medias_setores_atualizadas[setor] = float('nan')
            continue

    row = df_figura2[df_figura2['Indicador'] == current_setor]

    if not row.empty:
        media = row[monthly_columns].mean(axis=1).iloc[0]
        medias_setores_atualizadas[setor] = media
        print(f"  - {setor}: {media:.2f}")
    else:
        print(f"  - '{setor}' não encontrado.")
        medias_setores_atualizadas[setor] = float('nan')


print("\nDicionário de médias:")
print(medias_setores_atualizadas)
# Out:
# Médias mensais dos indicadores:
#   - Margem Bruta de Revenda: 29.98
#   - Margem Bruta de Distribuição: 22.82
#   - Preço de Realização do Produtor: 37.68
#   - ICMS: 18.10
#   - Preço Final GLP P13: 108.58
#
# Dicionário de médias:
# {'Margem Bruta de Revenda': np.float64(29.983333333333334), 'Margem Bruta de Distribuição': np.float64(22.821666666666662), 'Preço de Realização do Produtor': np.float64(37.681666666666665), 'ICMS': np.float64(18.09583333333333), 'Preço Final GLP P13': np.float64(108.5825)}

# %%
final_price_avg = medias_setores_atualizadas.get('Preço Final GLP P13')

if pd.isna(final_price_avg) or final_price_avg == 0:
    print("Não foi possível calcular as porcentagens porque o Preço Final ao Consumidor não foi encontrado ou é zero.")
else:
    print("\nPorcentagem de cada setor no preço final ao consumidor:")
    for setor, media in medias_setores_atualizadas.items():
        if setor == 'Preço Final GLP P13':
            continue

        if pd.notna(media):
            percentage = (media / final_price_avg) * 100
            print(f"  - {setor}: {percentage:.2f}%")
        else:
            print(f"  - {setor}: Não disponível para cálculo de porcentagem (média não encontrada).")
# Out:
# Porcentagem de cada setor no preço final ao consumidor:
#   - Margem Bruta de Revenda: 27.61%
#   - Margem Bruta de Distribuição: 21.02%
#   - Preço de Realização do Produtor: 34.70%
#   - ICMS: 16.67%

# %% [markdown]
# #FIGURA 3 - preço médio (2010-2025)
#
# Os dados foram retirados, em csv, da seguinte base de dados: https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/serie-historica-de-precos-de-combustiveis
#
# Após serem baixados, foram transformados em .zip e salvos no google drive, cujo link foi utilizado para a criação e desenvolvimento do código.

# %%
import os
import zipfile

# !pip install -U gdown

file_id = '1flfD9yVrsSu7gRhZru_6cHcATbbvREAh'
output_filename = 'downloaded_archive.zip'

print(f'Downloading file with ID: {file_id}...')
# !gdown --id {file_id} -O {output_filename}
print(f'File downloaded as {output_filename}')

extraction_path = 'extracted_files'
os.makedirs(extraction_path, exist_ok=True)

if os.path.exists(output_filename):
    with zipfile.ZipFile(output_filename, 'r') as zip_ref:
        zip_ref.extractall(extraction_path)
    print(f'All files extracted to: {extraction_path}')


    print(f'Contents of {extraction_path}:')
    for root, dirs, files in os.walk(extraction_path):
        for name in files:
            print(os.path.join(root, name))
        for name in dirs:
            print(os.path.join(root, name) + '/')
else:
    print(f'Error: {output_filename} not found. Download might have failed.')
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.24.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.2.25)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading file with ID: 1flfD9yVrsSu7gRhZru_6cHcATbbvREAh...
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1flfD9yVrsSu7gRhZru_6cHcATbbvREAh
# From (redirected): https://drive.google.com/uc?id=1flfD9yVrsSu7gRhZru_6cHcATbbvREAh&confirm=t&uuid=5d678a7e-42b8-4262-b00c-d2d7294f3f1e
# To: /content/downloaded_archive.zip
# 100% 217M/217M [00:02<00:00, 89.7MB/s]
# File downloaded as downloaded_archive.zip
# All files extracted to: extracted_files
# Contents of extracted_files:
# extracted_files/glp-2020-02.csv
# extracted_files/glp-2018-02.csv
# extracted_files/glp-2023-01.csv
# extracted_files/glp-2016-01.csv
# extracted_files/glp-2017-02.csv
# extracted_files/glp-2023-02.csv
# extracted_files/glp-2021-02.csv
# extracted_files/glp-2010-01.csv
# extracted_files/glp-2014-01.csv
# extracted_files/glp-2015-02.csv
# extracted_files/glp-2014-02.csv
# extracted_files/glp-2019-01.csv
# extracted_files/glp-2012-02.csv
# extracted_files/glp-2011-02.csv
# extracted_files/glp-2011-01.csv
# extracted_files/glp-2020-01.csv
# extracted_files/glp-2013-02.csv
# extracted_files/glp-2024-02.csv
# extracted_files/glp-2019-02.csv
# extracted_files/glp-2015-01.csv
# extracted_files/glp-2022-01.csv
# extracted_files/glp-2017-01.csv
# extracted_files/glp-2021-01.csv
# extracted_files/glp-2010-02.csv
# extracted_files/glp-2016-02.csv
# extracted_files/glp-2025-01.csv
# extracted_files/glp-2022-02.csv
# extracted_files/glp-2024-01.csv
# extracted_files/glp-2025-02.csv
# extracted_files/glp-2018-01.csv
# extracted_files/glp-2013-01.csv
# extracted_files/glp-2012-01.csv

# %%
import pandas as pd
import os

extraction_path = 'extracted_files'

csv_files = [f for f in os.listdir(extraction_path) if f.endswith('.csv')]

if not csv_files:
    print(f"No CSV files found in '{extraction_path}'.")
else:
    for csv_file in sorted(csv_files):
        file_path = os.path.join(extraction_path, csv_file)
        print(f"\n--- Data types for {csv_file} ---")
        try:

            df = pd.read_csv(file_path, delimiter=';')
            df.info()
        except Exception as e:
            print(f"Error reading {csv_file}: {e}")
# Out:
# --- Data types for glp-2010-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185607 entries, 0 to 185606
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     185607 non-null  object
#  1   Estado - Sigla     185607 non-null  object
#  2   Municipio          185607 non-null  object
#  3   Revenda            185607 non-null  object
#  4   CNPJ da Revenda    185607 non-null  object
#  5   Nome da Rua        185607 non-null  object
#  6   Numero Rua         185607 non-null  object
#  7   Complemento        28172 non-null   object
#  8   Bairro             185605 non-null  object
#  9   Cep                185607 non-null  object
#  10  Produto            185607 non-null  object
#  11  Data da Coleta     185607 non-null  object
#  12  Valor de Venda     185607 non-null  object
#  13  Valor de Compra    65184 non-null   object
#  14  Unidade de Medida  185607 non-null  object
#  15  Bandeira           185607 non-null  object
# dtypes: object(16)
# memory usage: 22.7+ MB
#
# --- Data types for glp-2010-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196586 entries, 0 to 196585
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     196586 non-null  object
#  1   Estado - Sigla     196586 non-null  object
#  2   Municipio          196586 non-null  object
#  3   Revenda            196586 non-null  object
#  4   CNPJ da Revenda    196586 non-null  object
#  5   Nome da Rua        196586 non-null  object
#  6   Numero Rua         196586 non-null  object
#  7   Complemento        42295 non-null   object
#  8   Bairro             196573 non-null  object
#  9   Cep                196586 non-null  object
#  10  Produto            196586 non-null  object
#  11  Data da Coleta     196586 non-null  object
#  12  Valor de Venda     196586 non-null  object
#  13  Valor de Compra    69601 non-null   object
#  14  Unidade de Medida  196586 non-null  object
#  15  Bandeira           196586 non-null  object
# dtypes: object(16)
# memory usage: 24.0+ MB
#
# --- Data types for glp-2011-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207883 entries, 0 to 207882
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     207883 non-null  object
#  1   Estado - Sigla     207883 non-null  object
#  2   Municipio          207883 non-null  object
#  3   Revenda            207883 non-null  object
#  4   CNPJ da Revenda    207883 non-null  object
#  5   Nome da Rua        207883 non-null  object
#  6   Numero Rua         207883 non-null  object
#  7   Complemento        45991 non-null   object
#  8   Bairro             207857 non-null  object
#  9   Cep                207883 non-null  object
#  10  Produto            207883 non-null  object
#  11  Data da Coleta     207883 non-null  object
#  12  Valor de Venda     207883 non-null  object
#  13  Valor de Compra    65044 non-null   object
#  14  Unidade de Medida  207883 non-null  object
#  15  Bandeira           207883 non-null  object
# dtypes: object(16)
# memory usage: 25.4+ MB
#
# --- Data types for glp-2011-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210134 entries, 0 to 210133
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     210134 non-null  object
#  1   Estado - Sigla     210134 non-null  object
#  2   Municipio          210134 non-null  object
#  3   Revenda            210134 non-null  object
#  4   CNPJ da Revenda    210134 non-null  object
#  5   Nome da Rua        210134 non-null  object
#  6   Numero Rua         210134 non-null  object
#  7   Complemento        46124 non-null   object
#  8   Bairro             210108 non-null  object
#  9   Cep                210134 non-null  object
#  10  Produto            210134 non-null  object
#  11  Data da Coleta     210134 non-null  object
#  12  Valor de Venda     210134 non-null  object
#  13  Valor de Compra    62721 non-null   object
#  14  Unidade de Medida  210134 non-null  object
#  15  Bandeira           210134 non-null  object
# dtypes: object(16)
# memory usage: 25.7+ MB
#
# --- Data types for glp-2012-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209900 entries, 0 to 209899
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     209900 non-null  object
#  1   Estado - Sigla     209900 non-null  object
#  2   Municipio          209900 non-null  object
#  3   Revenda            209900 non-null  object
#  4   CNPJ da Revenda    209900 non-null  object
#  5   Nome da Rua        209900 non-null  object
#  6   Numero Rua         209900 non-null  object
#  7   Complemento        46235 non-null   object
#  8   Bairro             209874 non-null  object
#  9   Cep                209900 non-null  object
#  10  Produto            209900 non-null  object
#  11  Data da Coleta     209900 non-null  object
#  12  Valor de Venda     209900 non-null  object
#  13  Valor de Compra    58020 non-null   object
#  14  Unidade de Medida  209900 non-null  object
#  15  Bandeira           209900 non-null  object
# dtypes: object(16)
# memory usage: 25.6+ MB
#
# --- Data types for glp-2012-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210866 entries, 0 to 210865
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     210866 non-null  object
#  1   Estado - Sigla     210866 non-null  object
#  2   Municipio          210866 non-null  object
#  3   Revenda            210866 non-null  object
#  4   CNPJ da Revenda    210866 non-null  object
#  5   Nome da Rua        210866 non-null  object
#  6   Numero Rua         210866 non-null  object
#  7   Complemento        46841 non-null   object
#  8   Bairro             210840 non-null  object
#  9   Cep                210866 non-null  object
#  10  Produto            210866 non-null  object
#  11  Data da Coleta     210866 non-null  object
#  12  Valor de Venda     210866 non-null  object
#  13  Valor de Compra    64688 non-null   object
#  14  Unidade de Medida  210866 non-null  object
#  15  Bandeira           210866 non-null  object
# dtypes: object(16)
# memory usage: 25.7+ MB
#
# --- Data types for glp-2013-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209102 entries, 0 to 209101
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     209102 non-null  object
#  1   Estado - Sigla     209102 non-null  object
#  2   Municipio          209102 non-null  object
#  3   Revenda            209102 non-null  object
#  4   CNPJ da Revenda    209102 non-null  object
#  5   Nome da Rua        209102 non-null  object
#  6   Numero Rua         209094 non-null  object
#  7   Complemento        46505 non-null   object
#  8   Bairro             209092 non-null  object
#  9   Cep                209102 non-null  object
#  10  Produto            209102 non-null  object
#  11  Data da Coleta     209102 non-null  object
#  12  Valor de Venda     209102 non-null  object
#  13  Valor de Compra    63609 non-null   object
#  14  Unidade de Medida  209102 non-null  object
#  15  Bandeira           209102 non-null  object
# dtypes: object(16)
# memory usage: 25.5+ MB
#
# --- Data types for glp-2013-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212689 entries, 0 to 212688
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     212689 non-null  object
#  1   Estado - Sigla     212689 non-null  object
#  2   Municipio          212689 non-null  object
#  3   Revenda            212689 non-null  object
#  4   CNPJ da Revenda    212689 non-null  object
#  5   Nome da Rua        212689 non-null  object
#  6   Numero Rua         212667 non-null  object
#  7   Complemento        47253 non-null   object
#  8   Bairro             212689 non-null  object
#  9   Cep                212689 non-null  object
#  10  Produto            212689 non-null  object
#  11  Data da Coleta     212689 non-null  object
#  12  Valor de Venda     212689 non-null  object
#  13  Valor de Compra    58310 non-null   object
#  14  Unidade de Medida  212689 non-null  object
#  15  Bandeira           212689 non-null  object
# dtypes: object(16)
# memory usage: 26.0+ MB
#
# --- Data types for glp-2014-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205186 entries, 0 to 205185
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     205186 non-null  object
#  1   Estado - Sigla     205186 non-null  object
#  2   Municipio          205186 non-null  object
#  3   Revenda            205186 non-null  object
#  4   CNPJ da Revenda    205186 non-null  object
#  5   Nome da Rua        205186 non-null  object
#  6   Numero Rua         205161 non-null  object
#  7   Complemento        44952 non-null   object
#  8   Bairro             205186 non-null  object
#  9   Cep                205186 non-null  object
#  10  Produto            205186 non-null  object
#  11  Data da Coleta     205186 non-null  object
#  12  Valor de Venda     205186 non-null  object
#  13  Valor de Compra    52338 non-null   object
#  14  Unidade de Medida  205186 non-null  object
#  15  Bandeira           205186 non-null  object
# dtypes: object(16)
# memory usage: 25.0+ MB
#
# --- Data types for glp-2014-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213453 entries, 0 to 213452
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     213453 non-null  object
#  1   Estado - Sigla     213453 non-null  object
#  2   Municipio          213453 non-null  object
#  3   Revenda            213453 non-null  object
#  4   CNPJ da Revenda    213453 non-null  object
#  5   Nome da Rua        213453 non-null  object
#  6   Numero Rua         213430 non-null  object
#  7   Complemento        46762 non-null   object
#  8   Bairro             213453 non-null  object
#  9   Cep                213453 non-null  object
#  10  Produto            213453 non-null  object
#  11  Data da Coleta     213453 non-null  object
#  12  Valor de Venda     213453 non-null  object
#  13  Valor de Compra    53198 non-null   object
#  14  Unidade de Medida  213453 non-null  object
#  15  Bandeira           213453 non-null  object
# dtypes: object(16)
# memory usage: 26.1+ MB
#
# --- Data types for glp-2015-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192999 entries, 0 to 192998
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     192999 non-null  object
#  1   Estado - Sigla     192999 non-null  object
#  2   Municipio          192999 non-null  object
#  3   Revenda            192999 non-null  object
#  4   CNPJ da Revenda    192999 non-null  object
#  5   Nome da Rua        192999 non-null  object
#  6   Numero Rua         192979 non-null  object
#  7   Complemento        45692 non-null   object
#  8   Bairro             192999 non-null  object
#  9   Cep                192999 non-null  object
#  10  Produto            192999 non-null  object
#  11  Data da Coleta     192999 non-null  object
#  12  Valor de Venda     192999 non-null  object
#  13  Valor de Compra    43903 non-null   object
#  14  Unidade de Medida  192999 non-null  object
#  15  Bandeira           192999 non-null  object
# dtypes: object(16)
# memory usage: 23.6+ MB
#
# --- Data types for glp-2015-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123646 entries, 0 to 123645
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     123646 non-null  object
#  1   Estado - Sigla     123646 non-null  object
#  2   Municipio          123646 non-null  object
#  3   Revenda            123646 non-null  object
#  4   CNPJ da Revenda    123646 non-null  object
#  5   Nome da Rua        123646 non-null  object
#  6   Numero Rua         123632 non-null  object
#  7   Complemento        33281 non-null   object
#  8   Bairro             123646 non-null  object
#  9   Cep                123646 non-null  object
#  10  Produto            123646 non-null  object
#  11  Data da Coleta     123646 non-null  object
#  12  Valor de Venda     123646 non-null  object
#  13  Valor de Compra    31039 non-null   object
#  14  Unidade de Medida  123646 non-null  object
#  15  Bandeira           123646 non-null  object
# dtypes: object(16)
# memory usage: 15.1+ MB
#
# --- Data types for glp-2016-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143226 entries, 0 to 143225
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     143226 non-null  object
#  1   Estado - Sigla     143226 non-null  object
#  2   Municipio          143226 non-null  object
#  3   Revenda            143226 non-null  object
#  4   CNPJ da Revenda    143226 non-null  object
#  5   Nome da Rua        143226 non-null  object
#  6   Numero Rua         143189 non-null  object
#  7   Complemento        38384 non-null   object
#  8   Bairro             143226 non-null  object
#  9   Cep                143226 non-null  object
#  10  Produto            143226 non-null  object
#  11  Data da Coleta     143226 non-null  object
#  12  Valor de Venda     143226 non-null  object
#  13  Valor de Compra    32332 non-null   object
#  14  Unidade de Medida  143226 non-null  object
#  15  Bandeira           143226 non-null  object
# dtypes: object(16)
# memory usage: 17.5+ MB
#
# --- Data types for glp-2016-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142753 entries, 0 to 142752
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     142753 non-null  object
#  1   Estado - Sigla     142753 non-null  object
#  2   Municipio          142753 non-null  object
#  3   Revenda            142753 non-null  object
#  4   CNPJ da Revenda    142753 non-null  object
#  5   Nome da Rua        142753 non-null  object
#  6   Numero Rua         142727 non-null  object
#  7   Complemento        37372 non-null   object
#  8   Bairro             142753 non-null  object
#  9   Cep                142753 non-null  object
#  10  Produto            142753 non-null  object
#  11  Data da Coleta     142753 non-null  object
#  12  Valor de Venda     142753 non-null  object
#  13  Valor de Compra    47823 non-null   object
#  14  Unidade de Medida  142753 non-null  object
#  15  Bandeira           142753 non-null  object
# dtypes: object(16)
# memory usage: 17.4+ MB
#
# --- Data types for glp-2017-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143201 entries, 0 to 143200
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     143201 non-null  object
#  1   Estado - Sigla     143201 non-null  object
#  2   Municipio          143201 non-null  object
#  3   Revenda            143201 non-null  object
#  4   CNPJ da Revenda    143201 non-null  object
#  5   Nome da Rua        143201 non-null  object
#  6   Numero Rua         143199 non-null  object
#  7   Complemento        35696 non-null   object
#  8   Bairro             143181 non-null  object
#  9   Cep                143201 non-null  object
#  10  Produto            143201 non-null  object
#  11  Data da Coleta     143201 non-null  object
#  12  Valor de Venda     143201 non-null  object
#  13  Valor de Compra    50277 non-null   object
#  14  Unidade de Medida  143201 non-null  object
#  15  Bandeira           143201 non-null  object
# dtypes: object(16)
# memory usage: 17.5+ MB
#
# --- Data types for glp-2017-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78465 entries, 0 to 78464
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Regiao - Sigla     78465 non-null  object
#  1   Estado - Sigla     78465 non-null  object
#  2   Municipio          78465 non-null  object
#  3   Revenda            78465 non-null  object
#  4   CNPJ da Revenda    78465 non-null  object
#  5   Nome da Rua        78465 non-null  object
#  6   Numero Rua         78463 non-null  object
#  7   Complemento        19547 non-null  object
#  8   Bairro             78450 non-null  object
#  9   Cep                78465 non-null  object
#  10  Produto            78465 non-null  object
#  11  Data da Coleta     78465 non-null  object
#  12  Valor de Venda     78465 non-null  object
#  13  Valor de Compra    26383 non-null  object
#  14  Unidade de Medida  78465 non-null  object
#  15  Bandeira           78465 non-null  object
# dtypes: object(16)
# memory usage: 9.6+ MB
#
# --- Data types for glp-2018-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108580 entries, 0 to 108579
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     108580 non-null  object
#  1   Estado - Sigla     108580 non-null  object
#  2   Municipio          108580 non-null  object
#  3   Revenda            108580 non-null  object
#  4   CNPJ da Revenda    108580 non-null  object
#  5   Nome da Rua        108580 non-null  object
#  6   Numero Rua         108569 non-null  object
#  7   Complemento        26066 non-null   object
#  8   Bairro             108555 non-null  object
#  9   Cep                108580 non-null  object
#  10  Produto            108580 non-null  object
#  11  Data da Coleta     108580 non-null  object
#  12  Valor de Venda     108580 non-null  object
#  13  Valor de Compra    33145 non-null   object
#  14  Unidade de Medida  108580 non-null  object
#  15  Bandeira           108580 non-null  object
# dtypes: object(16)
# memory usage: 13.3+ MB
#
# --- Data types for glp-2018-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113693 entries, 0 to 113692
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     113693 non-null  object
#  1   Estado - Sigla     113693 non-null  object
#  2   Municipio          113693 non-null  object
#  3   Revenda            113693 non-null  object
#  4   CNPJ da Revenda    113693 non-null  object
#  5   Nome da Rua        113693 non-null  object
#  6   Numero Rua         113663 non-null  object
#  7   Complemento        27875 non-null   object
#  8   Bairro             113676 non-null  object
#  9   Cep                113693 non-null  object
#  10  Produto            113693 non-null  object
#  11  Data da Coleta     113693 non-null  object
#  12  Valor de Venda     113693 non-null  object
#  13  Valor de Compra    32799 non-null   object
#  14  Unidade de Medida  113693 non-null  object
#  15  Bandeira           113693 non-null  object
# dtypes: object(16)
# memory usage: 13.9+ MB
#
# --- Data types for glp-2019-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113709 entries, 0 to 113708
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     113709 non-null  object
#  1   Estado - Sigla     113709 non-null  object
#  2   Municipio          113709 non-null  object
#  3   Revenda            113709 non-null  object
#  4   CNPJ da Revenda    113709 non-null  object
#  5   Nome da Rua        113709 non-null  object
#  6   Numero Rua         113697 non-null  object
#  7   Complemento        27459 non-null   object
#  8   Bairro             113683 non-null  object
#  9   Cep                113709 non-null  object
#  10  Produto            113709 non-null  object
#  11  Data da Coleta     113709 non-null  object
#  12  Valor de Venda     113709 non-null  object
#  13  Valor de Compra    32643 non-null   object
#  14  Unidade de Medida  113709 non-null  object
#  15  Bandeira           113709 non-null  object
# dtypes: object(16)
# memory usage: 13.9+ MB
#
# --- Data types for glp-2019-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114695 entries, 0 to 114694
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     114695 non-null  object
#  1   Estado - Sigla     114695 non-null  object
#  2   Municipio          114695 non-null  object
#  3   Revenda            114695 non-null  object
#  4   CNPJ da Revenda    114695 non-null  object
#  5   Nome da Rua        114695 non-null  object
#  6   Numero Rua         114683 non-null  object
#  7   Complemento        27112 non-null   object
#  8   Bairro             114678 non-null  object
#  9   Cep                114695 non-null  object
#  10  Produto            114695 non-null  object
#  11  Data da Coleta     114695 non-null  object
#  12  Valor de Venda     114695 non-null  object
#  13  Valor de Compra    38826 non-null   object
#  14  Unidade de Medida  114695 non-null  object
#  15  Bandeira           114695 non-null  object
# dtypes: object(16)
# memory usage: 14.0+ MB
#
# --- Data types for glp-2020-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114241 entries, 0 to 114240
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     114241 non-null  object
#  1   Estado - Sigla     114241 non-null  object
#  2   Municipio          114241 non-null  object
#  3   Revenda            114241 non-null  object
#  4   CNPJ da Revenda    114241 non-null  object
#  5   Nome da Rua        114241 non-null  object
#  6   Numero Rua         114224 non-null  object
#  7   Complemento        27171 non-null   object
#  8   Bairro             114241 non-null  object
#  9   Cep                114241 non-null  object
#  10  Produto            114241 non-null  object
#  11  Data da Coleta     114241 non-null  object
#  12  Valor de Venda     114241 non-null  object
#  13  Valor de Compra    29325 non-null   object
#  14  Unidade de Medida  114241 non-null  object
#  15  Bandeira           114241 non-null  object
# dtypes: object(16)
# memory usage: 13.9+ MB
#
# --- Data types for glp-2020-02.csv ---
# /tmp/ipykernel_218/2429581981.py:16: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=';')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45412 entries, 0 to 45411
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Regiao - Sigla     45412 non-null  object
#  1   Estado - Sigla     45412 non-null  object
#  2   Municipio          45412 non-null  object
#  3   Revenda            45412 non-null  object
#  4   CNPJ da Revenda    45412 non-null  object
#  5   Nome da Rua        45412 non-null  object
#  6   Numero Rua         45406 non-null  object
#  7   Complemento        11179 non-null  object
#  8   Bairro             45412 non-null  object
#  9   Cep                45412 non-null  object
#  10  Produto            45412 non-null  object
#  11  Data da Coleta     45412 non-null  object
#  12  Valor de Venda     45412 non-null  object
#  13  Valor de Compra    6141 non-null   object
#  14  Unidade de Medida  45412 non-null  object
#  15  Bandeira           45412 non-null  object
# dtypes: object(16)
# memory usage: 5.5+ MB
#
# --- Data types for glp-2021-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60280 entries, 0 to 60279
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Regiao - Sigla     60280 non-null  object
#  1   Estado - Sigla     60280 non-null  object
#  2   Municipio          60280 non-null  object
#  3   Revenda            60280 non-null  object
#  4   CNPJ da Revenda    60280 non-null  object
#  5   Nome da Rua        60280 non-null  object
#  6   Numero Rua         60280 non-null  object
#  7   Complemento        14323 non-null  object
#  8   Bairro             60280 non-null  object
#  9   Cep                60280 non-null  object
#  10  Produto            60280 non-null  object
#  11  Data da Coleta     60280 non-null  object
#  12  Valor de Venda     60280 non-null  object
#  13  Valor de Compra    0 non-null      float64
#  14  Unidade de Medida  60280 non-null  object
#  15  Bandeira           60280 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 7.4+ MB
#
# --- Data types for glp-2021-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89372 entries, 0 to 89371
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Regiao - Sigla     89372 non-null  object
#  1   Estado - Sigla     89372 non-null  object
#  2   Municipio          89372 non-null  object
#  3   Revenda            89372 non-null  object
#  4   CNPJ da Revenda    89372 non-null  object
#  5   Nome da Rua        89372 non-null  object
#  6   Numero Rua         89371 non-null  object
#  7   Complemento        21059 non-null  object
#  8   Bairro             89367 non-null  object
#  9   Cep                89372 non-null  object
#  10  Produto            89372 non-null  object
#  11  Data da Coleta     89372 non-null  object
#  12  Valor de Venda     89372 non-null  object
#  13  Valor de Compra    0 non-null      float64
#  14  Unidade de Medida  89372 non-null  object
#  15  Bandeira           89372 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 10.9+ MB
#
# --- Data types for glp-2022-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100133 entries, 0 to 100132
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     100133 non-null  object
#  1   Estado - Sigla     100133 non-null  object
#  2   Municipio          100133 non-null  object
#  3   Revenda            100133 non-null  object
#  4   CNPJ da Revenda    100133 non-null  object
#  5   Nome da Rua        100133 non-null  object
#  6   Numero Rua         100132 non-null  object
#  7   Complemento        23989 non-null   object
#  8   Bairro             100109 non-null  object
#  9   Cep                100133 non-null  object
#  10  Produto            100133 non-null  object
#  11  Data da Coleta     100133 non-null  object
#  12  Valor de Venda     100133 non-null  object
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  100133 non-null  object
#  15  Bandeira           100133 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 12.2+ MB
#
# --- Data types for glp-2022-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67371 entries, 0 to 67370
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Regiao - Sigla     67371 non-null  object
#  1   Estado - Sigla     67371 non-null  object
#  2   Municipio          67371 non-null  object
#  3   Revenda            67371 non-null  object
#  4   CNPJ da Revenda    67371 non-null  object
#  5   Nome da Rua        67371 non-null  object
#  6   Numero Rua         67363 non-null  object
#  7   Complemento        16043 non-null  object
#  8   Bairro             67360 non-null  object
#  9   Cep                67371 non-null  object
#  10  Produto            67371 non-null  object
#  11  Data da Coleta     67371 non-null  object
#  12  Valor de Venda     67371 non-null  object
#  13  Valor de Compra    0 non-null      float64
#  14  Unidade de Medida  67371 non-null  object
#  15  Bandeira           67371 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 8.2+ MB
#
# --- Data types for glp-2023-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105341 entries, 0 to 105340
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     105341 non-null  object
#  1   Estado - Sigla     105341 non-null  object
#  2   Municipio          105341 non-null  object
#  3   Revenda            105341 non-null  object
#  4   CNPJ da Revenda    105341 non-null  object
#  5   Nome da Rua        105341 non-null  object
#  6   Numero Rua         105341 non-null  object
#  7   Complemento        26414 non-null   object
#  8   Bairro             105323 non-null  object
#  9   Cep                105341 non-null  object
#  10  Produto            105341 non-null  object
#  11  Data da Coleta     105341 non-null  object
#  12  Valor de Venda     105341 non-null  object
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  105341 non-null  object
#  15  Bandeira           105341 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 12.9+ MB
#
# --- Data types for glp-2023-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121725 entries, 0 to 121724
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     121725 non-null  object
#  1   Estado - Sigla     121725 non-null  object
#  2   Municipio          121725 non-null  object
#  3   Revenda            121725 non-null  object
#  4   CNPJ da Revenda    121725 non-null  object
#  5   Nome da Rua        121725 non-null  object
#  6   Numero Rua         121725 non-null  object
#  7   Complemento        30491 non-null   object
#  8   Bairro             121699 non-null  object
#  9   Cep                121725 non-null  object
#  10  Produto            121725 non-null  object
#  11  Data da Coleta     121725 non-null  object
#  12  Valor de Venda     121725 non-null  object
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  121725 non-null  object
#  15  Bandeira           121725 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 14.9+ MB
#
# --- Data types for glp-2024-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122071 entries, 0 to 122070
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     122071 non-null  object
#  1   Estado - Sigla     122071 non-null  object
#  2   Municipio          122071 non-null  object
#  3   Revenda            122071 non-null  object
#  4   CNPJ da Revenda    122071 non-null  object
#  5   Nome da Rua        122071 non-null  object
#  6   Numero Rua         122071 non-null  object
#  7   Complemento        30373 non-null   object
#  8   Bairro             122047 non-null  object
#  9   Cep                122071 non-null  object
#  10  Produto            122071 non-null  object
#  11  Data da Coleta     122071 non-null  object
#  12  Valor de Venda     122071 non-null  object
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  122071 non-null  object
#  15  Bandeira           122071 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 14.9+ MB
#
# --- Data types for glp-2024-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38425 entries, 0 to 38424
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Regiao - Sigla     38425 non-null  object
#  1   Estado - Sigla     38425 non-null  object
#  2   Municipio          38425 non-null  object
#  3   Revenda            38425 non-null  object
#  4   CNPJ da Revenda    38425 non-null  object
#  5   Nome da Rua        38425 non-null  object
#  6   Numero Rua         38425 non-null  object
#  7   Complemento        9726 non-null   object
#  8   Bairro             38425 non-null  object
#  9   Cep                38425 non-null  object
#  10  Produto            38425 non-null  object
#  11  Data da Coleta     38425 non-null  object
#  12  Valor de Venda     38425 non-null  object
#  13  Valor de Compra    0 non-null      float64
#  14  Unidade de Medida  38425 non-null  object
#  15  Bandeira           38425 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 4.7+ MB
#
# --- Data types for glp-2025-01.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71780 entries, 0 to 71779
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Regiao - Sigla     71780 non-null  object
#  1   Estado - Sigla     71780 non-null  object
#  2   Municipio          71780 non-null  object
#  3   Revenda            71780 non-null  object
#  4   CNPJ da Revenda    71780 non-null  object
#  5   Nome da Rua        71780 non-null  object
#  6   Numero Rua         71780 non-null  object
#  7   Complemento        18684 non-null  object
#  8   Bairro             71780 non-null  object
#  9   Cep                71780 non-null  object
#  10  Produto            71780 non-null  object
#  11  Data da Coleta     71780 non-null  object
#  12  Valor de Venda     71780 non-null  object
#  13  Valor de Compra    0 non-null      float64
#  14  Unidade de Medida  71780 non-null  object
#  15  Bandeira           71780 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 8.8+ MB
#
# --- Data types for glp-2025-02.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53423 entries, 0 to 53422
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Regiao - Sigla     53423 non-null  object
#  1   Estado - Sigla     53423 non-null  object
#  2   Municipio          53423 non-null  object
#  3   Revenda            53423 non-null  object
#  4   CNPJ da Revenda    53423 non-null  int64
#  5   Nome da Rua        53423 non-null  object
#  6   Numero Rua         53423 non-null  object
#  7   Complemento        14220 non-null  object
#  8   Bairro             53423 non-null  object
#  9   Cep                53423 non-null  object
#  10  Produto            53423 non-null  object
#  11  Data da Coleta     53423 non-null  object
#  12  Valor de Venda     53423 non-null  object
#  13  Valor de Compra    0 non-null      float64
#  14  Unidade de Medida  53423 non-null  object
#  15  Bandeira           53423 non-null  object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 6.5+ MB

# %%
import pandas as pd
import os

extraction_path = 'extracted_files'
all_files = [os.path.join(extraction_path, f) for f in os.listdir(extraction_path) if f.endswith('.csv')]


li = []

for filename in all_files:
    try:

        df = pd.read_csv(filename, delimiter=';')
        li.append(df)
    except Exception as e:
        print(f"Error reading {filename}: {e}")


full_df = pd.concat(li, axis=0, ignore_index=True)

print("Combined DataFrame info:")
full_df.info()
# Out:
# /tmp/ipykernel_218/1118005845.py:13: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, delimiter=';')
# Combined DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4325947 entries, 0 to 4325946
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Regiao - Sigla     object
#  1   Estado - Sigla     object
#  2   Municipio          object
#  3   Revenda            object
#  4   CNPJ da Revenda    object
#  5   Nome da Rua        object
#  6   Numero Rua         object
#  7   Complemento        object
#  8   Bairro             object
#  9   Cep                object
#  10  Produto            object
#  11  Data da Coleta     object
#  12  Valor de Venda     object
#  13  Valor de Compra    object
#  14  Unidade de Medida  object
#  15  Bandeira           object
# dtypes: object(16)
# memory usage: 528.1+ MB

# %%
full_df['Data da Coleta'] = pd.to_datetime(full_df['Data da Coleta'], format='%d/%m/%Y', errors='coerce')

full_df['Ano'] = full_df['Data da Coleta'].dt.year


full_df['Valor de Venda'] = full_df['Valor de Venda'].str.replace(',', '.', regex=False).astype(float)


annual_avg_sales = full_df.groupby('Ano')['Valor de Venda'].mean().reset_index()

print("\nAnnual Average Sales Value:")
display(annual_avg_sales)
# Out:
# Annual Average Sales Value:
#      Ano  Valor de Venda
# 0   2010       38.617305
# 1   2011       38.946177
# 2   2012       39.848004
# 3   2013       41.722103
# 4   2014       43.616130
# 5   2015       48.086297
# 6   2016       55.226780
# 7   2017       59.006064
# 8   2018       68.929588
# 9   2019       69.935576
# 10  2020       71.160996
# 11  2021       93.292859
# 12  2022      110.824771
# 13  2023      104.998137
# 14  2024      103.651674
# 15  2025      109.697406

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
plt.figure(figsize=(12, 6))

ax = sns.barplot(x='Ano', y='Valor de Venda', data=annual_avg_sales, color='#4682B4') # SteelBlue, a darker blue


for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 9),
                textcoords='offset points')

plt.title('Média Anual do Valor de Venda (2010-2025)')
plt.xlabel('Ano')
plt.ylabel('Média do Valor de Venda')
plt.xticks(rotation=45)


plt.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# #FIGURA 4- comparação entre o preço do produtor e as margens
#
# Os dados utilizados foram extraídos de pdfs da Sindigás (https://www.sindigas.org.br/?page_id=3026) e adicionados a uma planilha em Excel.
# Para facilitar o acesso de todos e facilitar a reprodutibilidade do código, a planilha foi adicionada ao repositório do GitHub e seu link utilizado no código.

# %%
import pandas as pd


excel_url = 'https://github.com/annalocvf/Estudo-GLP-TCC-IC-UFOP/raw/main/Capitulo1/pre%C3%A7o-produtor-%20margem-distribui%C3%A7%C3%A3o-margem-revenda.xlsx'

def read_excel_sheets_to_dataframe(excel_url):
    """
    Reads all sheets from an Excel file into a single pandas DataFrame,
    adding a 'Ano' column based on the sheet name.
    """
    xls = pd.ExcelFile(excel_url)
    all_dfs = []

    for sheet_name in xls.sheet_names:

        try:
            year = int(sheet_name)
        except ValueError:

            print(f"Skipping sheet '{sheet_name}' as it's not a valid year.")
            continue

        df_sheet = pd.read_excel(xls, sheet_name=sheet_name)
        df_sheet['Ano'] = year
        all_dfs.append(df_sheet)


    if all_dfs:
        combined_df = pd.concat(all_dfs, ignore_index=True)
        return combined_df
    else:
        return pd.DataFrame()


df_combined = read_excel_sheets_to_dataframe(excel_url)

display(df_combined.head())
print(f"\nTotal rows in combined DataFrame: {len(df_combined)}")
display(df_combined.info())
# Out:
#                  Variável    Jan    Fev    Mar    Abr    Mai    Jun    Jul  \
# 0       Preço do produtor  23.96  23.28  23.32  22.39  22.34  22.35  23.34
# 1  Margem de distribuição  13.73  14.82  15.44  16.36  16.49  17.32  15.94
# 2       Margem de revenda  18.09  17.15  17.31  17.07  16.65  18.50  17.66
# 3       Preço do produtor  25.24  25.51  25.54  25.55  26.50  26.49  26.46
# 4  Margem de distribuição  16.36  14.94  15.20  15.28  14.12  14.98  14.49
#
#      Ago    Set    Out    Nov    Dez   Ano
# 0  23.38  23.36  23.30  25.17  25.22  2018
# 1  16.19  16.27  17.36  17.12  15.48  2018
# 2  17.09  17.04  16.49  16.64  16.72  2018
# 3  24.35  24.32  24.75  25.79  26.62  2019
# 4  16.29  16.21  15.63  14.83  13.86  2019
# Total rows in combined DataFrame: 21
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Variável  21 non-null     object
#  1   Jan       21 non-null     float64
#  2   Fev       21 non-null     float64
#  3   Mar       21 non-null     float64
#  4   Abr       21 non-null     float64
#  5   Mai       21 non-null     float64
#  6   Jun       21 non-null     float64
#  7   Jul       21 non-null     float64
#  8   Ago       21 non-null     float64
#  9   Set       20 non-null     float64
#  10  Out       21 non-null     float64
#  11  Nov       21 non-null     float64
#  12  Dez       21 non-null     float64
#  13  Ano       21 non-null     int64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 2.4+ KB
# None

# %%
month_columns = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']


annual_avg_by_year = df_combined.groupby(['Ano', 'Variável'])[month_columns].mean().reset_index()


annual_avg_by_year['Média Anual'] = annual_avg_by_year[month_columns].mean(axis=1)

display(annual_avg_by_year[['Ano', 'Variável', 'Média Anual']])
# Out:
#      Ano                Variável  Média Anual
# 0   2018  Margem de distribuição    16.043333
# 1   2018       Margem de revenda    17.200833
# 2   2018       Preço do produtor    23.450833
# 3   2019  Margem de distribuição    15.182500
# 4   2019       Margem de revenda    16.784167
# 5   2019       Preço do produtor    25.593333
# 6   2020  Margem de distribuição    13.463333
# 7   2020       Margem de revenda    17.549091
# 8   2020       Preço do produtor    27.347500
# 9   2021  Margem de distribuição    11.426667
# 10  2021       Margem de revenda    21.795000
# 11  2021       Preço do produtor    44.587500
# 12  2022  Margem de distribuição    15.988333
# 13  2022       Margem de revenda    28.785833
# 14  2022       Preço do produtor    52.467500
# 15  2023  Margem de distribuição    19.267500
# 16  2023       Margem de revenda    33.026667
# 17  2023       Preço do produtor    36.598333
# 18  2024  Margem de distribuição    20.150833
# 19  2024       Margem de revenda    30.526667
# 20  2024       Preço do produtor    34.700000

# %%
import matplotlib.pyplot as plt
import seaborn as sns


color_palette = {
    'Preço do produtor': '#1f77b4',
    'Margem de distribuição': '#ff7f0e',
    'Margem de revenda': '#2ca02c'
}

plt.figure(figsize=(12, 7))

sns.barplot(
    data=annual_avg_by_year,
    x='Ano',
    y='Média Anual',
    hue='Variável',
    palette=color_palette,

    hue_order=['Preço do produtor', 'Margem de distribuição', 'Margem de revenda']
)

plt.title('Média Anual por Variável e Ano')
plt.xlabel('Ano')
plt.ylabel('R$ por botijão, p-13')
plt.legend(title='Variável', loc='upper right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
